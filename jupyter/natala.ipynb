# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import scipy.stats as stats
import math
import sys

sys.path.append("./markdown.py")
import markdown as md

from matplotlib import style
from matplotlib.pyplot import figure
style.use('ggplot')
plt_height = 7
plt_length = 18

# %%
W = [0, 18.8, 30.55]
m = [0, 15, 40]

figure(1, figsize=(plt_length, plt_height)) 
plt.plot(m, W)

plt.xlabel("Prąd [A]")
plt.ylabel("Czas [s]")

plt.margins(0.01, 0.02)
plt.savefig("./png/natala.png", bbox_inches = 'tight')
plt.savefig("./pdf/natala.pdf", bbox_inches = 'tight')
plt.show()

# %%
W = [1000, 384.8, 171.5]
m = [0, 15, 40]

figure(1, figsize=(plt_length, plt_height)) 
plt.plot(m, W)

plt.xlabel("Prąd [A]")
plt.ylabel("Czas [s]")

plt.margins(0.01, 0.02)
plt.savefig("./png/natala.png", bbox_inches = 'tight')
plt.savefig("./pdf/natala.pdf", bbox_inches = 'tight')
plt.show()

# %%
def altspace(start, step, count, endpoint=False, **kwargs):
    stop = start+(step*count)
    return np.linspace(start, stop, count, endpoint=endpoint, **kwargs)

V = [3126,3147,3148,3147,3147,3146,3147,3149,3142,3148,3145,3146,3147,3146,3147,3127,
3,3,1,3,1,2,1,2,1,19,3,4,3,3,2,2,8,1,4,2,2,2,12,2,3,3,0,2,3,9,3,2,3086,3144,3145
,3146,3147,3147,3147,3136,3139,3145,3146,3146,3148,3147,3159,3147,3146,3145,3147
,3145,3144,3141,3147,3147,3145,3148,3147,3139,3145,3149,3145,3144,3143,0,2,3,2,1
,2,8,5,2,3,2,3,4,0,2,0,3,3,3,1,16,2,1,1,1,3,0,0,3,2,3,1,0,3128,3137,3146,3147,3141,
3147,3146,3146,3172,3147,3146,3142,3144,3145,3145,3145,3147,3148,3150,3146,3148,
3145,3146,3146,3141,3143,3146,3147,3147,3146,3146,3147,0,2,1,8,17,3,1,1,2,2,1
,0,4,3,2,3,4,14,10,2,0,2,2,0,0,2,1,2,0,1,1,0,2,3137,3141,3149,3147,3146,3144,3142,
3145,3143,3146,3147,3145,3146,3146,3149,3147,3147,3143,3145,3146,3147,3147,3139,
3148,3148,3148,3147,3147,3145,3144,3145,3146,1,3,0,3,2,2,2,2,8,5,3,2,2,3,2,0,8
,0,2,2,1,2,6,2,1,2,3,1,0,2,1,0,3,3131,3143,3144,3145,3146,3147,3144,3146,3146,3148,
3159,3144,3145,3144,3146,3147,3147,3146,3147,3149,3147,3147,3144,3143,3146,3147,
3146,3145,3147,3146,3146,3147,0,2,1,2,2,5,6,2,2,3,1,1,2,5,0,1,1,0,3,8,3,2,2,1
,2,3,8,1,1,2,15,1,1,3132,3143,3145,3145,3144,3142,3146,3147,3145,3145,3146,3146,
3147,3146,3146,3147,3142,3142,3143,3146,3145,3145,3145,3147,3162,3146,3147,3146,
3145,3144,3145,3146,1,2,1,2,3,2,2,1,3,1,4,7,3,2,1,2,2,0,0,16,2,1,2,1,0,1,1,1,1,1
,0,0,3,3127,3142,3146,3147,3144,3145,3145,3147,3149,3145,3144,3145,3147,3148,3149,
3148,3147,3146,3147,3148,3147,3145,3145,3146,3147,3148,3147,3146,3145,3149,3151,
3147,1618,0,1,2,1,1,2,0,3,3,2,2,2,2,2,1,1,4,1,2,2,2,1,2,1,1,1,2,2,4,2,2,3,3119
,3142,3145,3142,3142,3143,3148,3145,3147,3148,3149,3147,3147,3148,3146,3143,3143
,3142,3153,3147,3148,3147,3146,3146,3146,3148,3171,3144,3144,3147,3148,3146,2492
,2,3,2,2,3,1,3,2,1,2,1,4,6,3,1,3,2,1,2,13,15,2,3,1,1,4,2,2]

t = altspace(0, 1/200, len(V))
#t = np.linspace(0, 0.25, len(V))



figure(1, figsize=(plt_length, plt_height)) 
plt.plot(t, V)

plt.margins(0.01, 0.02)
#plt.savefig("./png/natala.png", bbox_inches = 'tight')
#plt.savefig("./pdf/natala.pdf", bbox_inches = 'tight')
plt.show()

# %%
len(V)
# Out:
# 500
